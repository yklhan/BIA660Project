# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import csv

# %%
def write_to_file(line_list, file_name):
    with open(file_name, 'w') as writer:
        for line in line_list:
            writer.write(line)
            writer.write('\n')

# %%
def review_clean(text):
    pro = ""
    con = ""
    sents = text.split("\n")
    try:
        pro_index = sents.index("Pros")
        con_index = sents.index("Cons")
    except:
        return pro, con
    for i in range(pro_index+1, con_index):
        pro += sents[i]
    for j in range(con_index+1, len(sents)-1):
        con += sents[j]
    return pro, con

# %%
def scrape(url, pageNum):
    reviews_storage = []
    pros_storage = []
    cons_storage = []
    
    #open the browser and visit the url
    driver = webdriver.Chrome('./chromedriver')
    driver.get(url)
    time.sleep(2)
    print ('attempting to sign in')
            
    driver.find_element_by_id("userEmail").send_keys("gonzalez.o1991@gmail.com")
    driver.find_element_by_id("userPassword").send_keys("SharedPassword1")
    driver.find_element_by_css_selector('button[name="submit"]').click()
    time.sleep(2) 
    
    driver.get('https://www.glassdoor.com/Reviews/Amazon-Reviews-E6036.htm')   
    already_seen=set()#keeps track of reviews we have already seen. 
     
    limit = 0

    reviews=driver.find_elements_by_css_selector('li[class="empReview cf"]')
    #print(len(reviews),' Reviews found\n')
    
    while limit < pageNum:
        print("To infinity and beyond! We're getting close, on %d now! page " % (limit))
       
        for review in reviews:
            reviews_storage.append(review.text)
            pro, con = review_clean(review.text)
            pros_storage.append(pro)
            cons_storage.append(con)
            
        driver.find_element_by_css_selector('a[class="pagination__ArrowStyle__nextArrow  "]').click()
        time.sleep(2)
        print ("entering new page for review mining")
        limit = limit + 1
        reviews=driver.find_elements_by_css_selector('li[class="empReview cf"]')#
        #print(len(reviews),' Reviews found\n')

    
    time.sleep(2)
    print('mined all reviews within', pageNum, 'page')
    print(len(reviews_storage), " reviews recorded")
    print(len(pros_storage), " pros recorded")
    print(len(cons_storage), " cons recorded")
    return reviews_storage, pros_storage, cons_storage

# %%
url='https://www.glassdoor.com/profile/login_input.htm?userOriginHook=HEADER_SIGNIN_LINK'
scrape_page = 50
reviews, pros, cons = scrape(url, scrape_page)
# Out:
# attempting to sign in
# To infinity and beyond! We're getting close, on 0 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 1 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 2 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 3 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 4 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 5 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 6 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 7 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 8 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 9 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 10 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 11 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 12 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 13 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 14 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 15 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 16 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 17 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 18 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 19 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 20 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 21 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 22 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 23 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 24 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 25 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 26 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 27 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 28 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 29 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 30 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 31 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 32 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 33 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 34 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 35 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 36 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 37 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 38 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 39 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 40 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 41 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 42 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 43 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 44 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 45 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 46 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 47 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 48 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 49 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 50 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 51 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 52 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 53 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 54 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 55 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 56 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 57 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 58 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 59 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 60 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 61 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 62 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 63 now! page
# entering new page for review mining
# To infinity and beyond! We're getting close, on 64 now! page
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-5-f3ed32b31cae> in <module>
#       1 url='https://www.glassdoor.com/profile/login_input.htm?userOriginHook=HEADER_SIGNIN_LINK'
#       2 scrape_page = 260
# ----> 3 reviews, pros, cons = scrape(url, scrape_page)
#
# <ipython-input-4-24ca4db748bb> in scrape(url, pageNum)
#      32             cons_storage.append(con)
#      33
# ---> 34         driver.find_element_by_css_selector('a[class="pagination__ArrowStyle__nextArrow  "]').click()
#      35         time.sleep(2)
#      36         print ("entering new page for review mining")
#
# D:\miniconda\envs\tf\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# D:\miniconda\envs\tf\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# D:\miniconda\envs\tf\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# D:\miniconda\envs\tf\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"a[class="pagination__ArrowStyle__nextArrow  "]"}
#   (Session info: chrome=84.0.4147.105)

# %%
write_to_file(reviews, 'project_review.txt')
write_to_file(pros, 'project_pro.txt')
write_to_file(cons, 'project_con.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cd9e1214aa10> in <module>
# ----> 1 write_to_file(reviews, 'project_review.txt')
#       2 write_to_file(pros, 'project_pro.txt')
#       3 write_to_file(cons, 'project_con.txt')
#
# NameError: name 'reviews' is not defined
